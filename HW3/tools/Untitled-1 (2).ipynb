# %%
pip install opencv-python-headless numpy open3d
# Out:
# Requirement already satisfied: opencv-python-headless in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (1.23.0)
# Requirement already satisfied: open3d in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (0.18.0)
# Requirement already satisfied: dash>=2.6.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from open3d) (2.18.2)
# Requirement already satisfied: werkzeug>=2.2.3 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from open3d) (3.0.6)
# Requirement already satisfied: nbformat>=5.7.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from open3d) (5.10.4)
# Requirement already satisfied: configargparse in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from open3d) (1.7)
# Requirement already satisfied: ipywidgets>=8.0.4 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from open3d) (8.1.5)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (3.0.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (5.24.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (4.12.2)
# Requirement already satisfied: requests in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (2.32.3)
# Requirement already satisfied: retrying in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from dash>=2.6.0->open3d) (75.1.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipywidgets>=8.0.4->open3d) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipywidgets>=8.0.4->open3d) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipywidgets>=8.0.4->open3d) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipywidgets>=8.0.4->open3d) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipywidgets>=8.0.4->open3d) (3.0.13)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from nbformat>=5.7.0->open3d) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from werkzeug>=2.2.3->open3d) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (1.9.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.21.0)
# Requirement already satisfied: backcall in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: decorator in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (1.2.2)
# Requirement already satisfied: colorama in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (305.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (9.0.0)
# Requirement already satisfied: packaging in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from requests->dash>=2.6.0->open3d) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from requests->dash>=2.6.0->open3d) (2024.8.30)
# Requirement already satisfied: six>=1.7.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from retrying->dash>=2.6.0->open3d) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\omidtavasolifar\anaconda3\envs\tavasolifar-sod\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np

image_folder_path = "C:/Users/OmidTavasolifar/Downloads/Compressed/100831_155323_MultiCamera0_subset_db"

stereo = cv2.StereoBM_create(numDisparities=64, blockSize=15)

focal_length = 718.856
baseline = 0.573

def compute_depth_map(left_img, right_img):
    if left_img is None or right_img is None:
        raise ValueError("One of the images is empty. Check the file paths.")
    
    left_gray = cv2.cvtColor(left_img, cv2.COLOR_BGR2GRAY)
    right_gray = cv2.cvtColor(right_img, cv2.COLOR_BGR2GRAY)
    
    disparity = stereo.compute(left_gray, right_gray).astype(np.float32) / 16.0
    
    disparity[disparity <= 0] = 0.1
    
    depth = (focal_length * baseline) / disparity
    return depth

files = sorted(os.listdir(image_folder_path))

depth_maps = []
for i in range(0, len(files), 2): 
    left_img_path = os.path.join(image_folder_path, files[i])
    right_img_path = os.path.join(image_folder_path, files[i + 1])
    
    left_img = cv2.imread(left_img_path)
    right_img = cv2.imread(right_img_path)
    
    try:
        depth = compute_depth_map(left_img, right_img)
        depth_maps.append(depth)
    except ValueError as e:
        print(f"Skipping pair {files[i]} and {files[i + 1]}: {e}")

print(f"Generated depth maps for {len(depth_maps)} image pairs.")


import matplotlib.pyplot as plt

for i, depth in enumerate(depth_maps):
    plt.figure(figsize=(10, 6))
    plt.imshow(depth, cmap='jet')
    plt.colorbar(label="Depth (meters)")
    plt.title(f"Depth Map {i + 1}")
    plt.xlabel("Image Width (pixels)")
    plt.ylabel("Image Height (pixels)")
    plt.show()

# %%
import open3d as o3d
import numpy as np


cx = 607.1928  
cy = 185.2157  
fx = 718.856   
fy = 718.856   

def depth_to_point_cloud(depth_map):
    h, w = depth_map.shape
    points = []
    for v in range(h):
        for u in range(w):
            z = depth_map[v, u]
            if z > 0:
                x = (u - cx) * z / fx
                y = (v - cy) * z / fy
                points.append([x, y, z])
    return np.array(points)

point_clouds = []
for depth in depth_maps:
    points = depth_to_point_cloud(depth)
    pc = o3d.geometry.PointCloud()
    pc.points = o3d.utility.Vector3dVector(points)
    point_clouds.append(pc)

print(f"Generated {len(point_clouds)} point clouds.")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hope.KingsMan\AppData\Local\Temp\ipykernel_14176\3755869466.py", line 26, in <module>
#     points = depth_to_point_cloud(depth)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hope.KingsMan\AppData\Local\Temp\ipykernel_14176\3755869466.py", line None, in depth_to_point_cloud
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "c:\Users\Hope.KingsMan\AppData\Local\Programs\Python\Python311\Lib\site-packages\executing\executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
trajectory = []  
for i in range(len(point_clouds) - 1):
    source = point_clouds[i]
    target = point_clouds[i + 1]
    
    threshold = 0.02 
    icp_result = o3d.pipelines.registration.registration_icp(
        source, target, threshold, 
        np.eye(4), 
        o3d.pipelines.registration.TransformationEstimationPointToPoint()
    )
    
    
    trajectory.append(icp_result.transformation)

    print(f"Transformation from frame {i} to {i + 1}:\n{icp_result.transformation}")

# %%
import matplotlib.pyplot as plt

camera_positions = [np.array([0, 0, 0])]
current_position = np.eye(4)

for transformation in trajectory:
    current_position = current_position @ transformation
    camera_positions.append(current_position[:3, 3])  

camera_positions = np.array(camera_positions)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(camera_positions[:, 0], camera_positions[:, 1], camera_positions[:, 2], '-o')
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.title("Camera Trajectory")
plt.show()

# %%
output_folder = "point_cloud_frames"
os.makedirs(output_folder, exist_ok=True)

for i, pc in enumerate(point_clouds):
    o3d.visualization.draw_geometries_with_animation_callback([pc],lambda vis: vis.capture_screen_image(f"{output_folder}/frame_{i:04d}.png"),steps_per_frame=5,)

import cv2
import glob

images = sorted(glob.glob(f"{output_folder}/*.png"))
frame = cv2.imread(images[0])
height, width, _ = frame.shape
video = cv2.VideoWriter("output_video.mp4", cv2.VideoWriter_fourcc(*'mp4v'), 30, (width, height))

for image_path in images:
    frame = cv2.imread(image_path)
    video.write(frame)

video.release()
print("Video created: output_video.mp4")
